# %%
import numpy as np
import pandas as pd
from sergio import sergio

import sys
locate_python = sys.exec_prefix
print(locate_python)
# Out:
# C:\Users\moha456\Anaconda3\envs\my_env

# %%
print("My numpy version is: ", np.__version__)
# Out:
# My numpy version is:  1.23.1

# %% [markdown]
# # Simulate Clean Data _ Steady-State Simulation

# %%
sim = sergio(number_genes=100, number_bins = 9, number_sc = 300, noise_params = 1, decays=0.8, sampling_state=15, noise_type='dpd')
sim.build_graph(input_file_taregts ='steady-state_input_GRN.txt', input_file_regs='steady-state_input_MRs.txt', shared_coop_state=2)
sim.simulate()
expr = sim.getExpressions()
expr_clean_ss = np.concatenate(expr, axis = 1)
expr_clean_ss[1:5]
# Out:
# Start simulating new level
# There are 4 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 6 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 90 genes to simulate in this layer
# Done with current level
# array([[ 5.34636163, 10.15472944, 13.4110785 , ...,  4.40635367,
#          1.5057542 ,  2.89006704],
#        [ 1.40264716,  2.64835836,  1.86487056, ...,  0.        ,
#          0.11885888,  0.69145603],
#        [ 1.17105205,  2.06508959,  2.33837001, ...,  1.31163762,
#          0.03605712,  0.77675646],
#        [ 2.48020689,  5.99595698,  4.4869089 , ...,  2.500643  ,
#          0.3657771 ,  3.55296207]])

# %%
# Now each row represents a gene
# Each column represents a simulated single-cell.

# %% [markdown]
# # Simulate Clean Data _ Steady State Simulation for single cell data

# %% [markdown]
# # Output

# %%
# save to csv
df_output.to_csv('GeneExpression_SingleCell.csv')

# %% [markdown]
# # Run SERGIO with CRISPRa/i gene perturbations

# %%
sim = sergio(number_genes=100, number_bins = 9, number_sc = 300, noise_params = 1, decays=0.8, sampling_state=15, noise_type='dpd')
sim.build_graph(input_file_taregts ='steady-state_input_GRN_CRISPRai.txt', input_file_regs='steady-state_input_MRs_CRISPRai.txt', shared_coop_state=2)
sim.simulate()
expr = sim.getExpressions()
expr_clean_ss = np.concatenate(expr, axis = 1)
expr_clean_ss[1:5]
# Out:
# Start simulating new level
# There are 4 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 6 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 90 genes to simulate in this layer
# Done with current level
# array([[5.64306085e+00, 6.69286286e+00, 7.28493528e+00, ...,
#         3.83039223e+00, 1.21773168e+01, 3.71751502e+00],
#        [5.13461770e+00, 3.13293236e+00, 2.90299176e+00, ...,
#         8.03489528e-03, 1.97092481e+00, 2.93194405e+00],
#        [3.76433754e-01, 3.74113247e+00, 3.90962165e+00, ...,
#         2.65715096e-03, 1.33926597e+00, 2.21118935e+00],
#        [9.16816513e-01, 1.95697563e+00, 4.69479749e+00, ...,
#         2.67330334e+00, 3.79982141e+00, 3.05993283e+00]])

# %%
expr_clean_ss 
df_output = pd.DataFrame(expr_clean_ss) 
df_output
# Out:
#          0          1         2          3          4          5     \
# 0    7.145300   2.026322  7.706799   9.908142   4.129176   2.956306
# 1    5.643061   6.692863  7.284935  11.706380   2.834795   5.621216
# 2    5.134618   3.132932  2.902992   2.179390   3.701788   1.335079
# 3    0.376434   3.741132  3.909622   3.526458   1.816609   1.003501
# 4    0.916817   1.956976  4.694797   2.140745   0.581142   0.769664
# ..        ...        ...       ...        ...        ...        ...
# 95   1.651754   1.733988  0.847236   5.954545   0.555183   0.358384
# 96   1.481192   8.304693  0.898428   2.032002   5.984957   2.906723
# 97   4.325201  12.190260  1.809529   2.567354   9.749664   4.822741
# 98  16.046504   7.232514  8.404886   9.827137  10.712481  17.189726
# 99   5.974768   7.244316  7.847051   1.686228  13.556892   4.653425
#
#          6          7          8          9     ...      2690       2691  \
# 0    4.904191   8.494682   9.244866   6.473535  ...  0.606966   6.796659
# 1    4.944250   8.505437   3.268306   6.182355  ...  1.578462   5.295631
# 2    2.117646   2.640187   2.220508   3.023754  ...  1.877896   4.584972
# 3    2.665386   2.605734   2.374144   2.964456  ...  3.866255   1.987892
# 4    6.405633   2.233357   3.207331   0.154664  ...  0.732889   4.096318
# ..        ...        ...        ...        ...  ...       ...        ...
# 95   4.556018   6.658213   2.970865   1.912471  ...  4.392246   4.038380
# 96   5.594746   1.268709   1.894345   3.260553  ...  0.801854   4.932552
# 97   3.850237   2.367970   2.096123   9.976171  ...  3.416876   4.119437
# 98  10.235375  10.361368  12.396783  11.579018  ...  6.169389  14.419007
# 99   5.479388   3.151428   5.973601   7.319047  ...  3.884625   5.672495
#
#          2692       2693      2694      2695       2696      2697       2698  \
# 0    5.917902   2.742316  2.393083  1.923377   0.222177  0.650354   6.937014
# 1    3.236776   4.057009  2.909244  4.611785   1.701780  3.830392  12.177317
# 2    0.029390   0.739743  2.704367  1.330687   2.096688  0.008035   1.970925
# 3    2.090678   1.358281  2.049346  0.506245   0.652818  0.002657   1.339266
# 4    2.448893   1.886835  0.824910  0.088575   0.559171  2.673303   3.799821
# ..        ...        ...       ...       ...        ...       ...        ...
# 95   2.204768   1.394756  3.470440  4.139400   1.413142  2.155733   5.204397
# 96   1.955314   3.313573  0.763865  0.054032   1.665418  4.668815   2.179328
# 97   0.784654   5.431450  1.672045  2.971166   4.121063  2.590681   6.166624
# 98  12.695013  10.354215  7.382483  7.934993  13.426284  9.391394   9.388024
# 99   2.299157   9.706610  3.837108  3.411281   2.835200  7.171276   9.431519
#
#         2699
# 0   3.542073
# 1   3.717515
# 2   2.931944
# 3   2.211189
# 4   3.059933
# ..       ...
# 95  6.745283
# 96  0.806547
# 97  1.184167
# 98  9.355809
# 99  4.029858
#
# [100 rows x 2700 columns]

# %%
# save to csv
df_output.to_csv('GeneExpression_CRISPRai_perturb.csv')

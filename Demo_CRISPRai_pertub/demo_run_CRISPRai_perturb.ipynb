# %%
import numpy as np
import pandas as pd
from sergio import sergio

import sys
locate_python = sys.exec_prefix
print(locate_python)
# Out:
# C:\Users\moha456\Anaconda3\envs\my_env

# %%
print("My numpy version is: ", np.__version__)
# Out:
# My numpy version is:  1.23.1

# %% [markdown]
# # Run SERGIO with CRISPRa gene perturbations

# %%
sim = sergio(number_genes=100, number_bins = 9, number_sc = 300, noise_params = 1, decays=0.8, sampling_state=15, noise_type='dpd')
sim.build_graph(input_file_taregts ='steady-state_input_GRN_CRISPRai.txt', input_file_regs='steady-state_input_MRs_CRISPRa.txt', shared_coop_state=2)
sim.simulate()
expr = sim.getExpressions()
expr_clean_ss = np.concatenate(expr, axis = 1)
expr_clean_ss[1:5]
# Out:
# Start simulating new level
# There are 4 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 6 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 90 genes to simulate in this layer
# Done with current level
# array([[ 9.63814844, 11.1801481 ,  8.76942072, ...,  4.75461467,
#          2.5473979 ,  2.31701469],
#        [ 1.86589848,  5.90146296,  2.3022299 , ...,  1.36442521,
#          0.33275216,  0.6059647 ],
#        [ 2.8288493 ,  2.71331503,  1.82643014, ...,  0.36360312,
#          0.47051152,  2.1079605 ],
#        [ 2.21603614,  5.68006374,  7.62100019, ...,  1.94734576,
#          0.60321543,  0.0669293 ]])

# %%
expr_clean_ss 
df_output = pd.DataFrame(expr_clean_ss) 
df_output
# Out:
#          0          1          2          3          4          5     \
# 0    6.386259  13.615524  11.152102   5.608334   4.247065   1.298232
# 1    9.638148  11.180148   8.769421   1.915464   7.882664  10.161853
# 2    1.865898   5.901463   2.302230   3.052998   6.086112   6.353275
# 3    2.828849   2.713315   1.826430   1.095779   1.043548   1.577042
# 4    2.216036   5.680064   7.621000   0.102184   6.407162   4.187375
# ..        ...        ...        ...        ...        ...        ...
# 95   0.815020   0.592629   0.307373   4.250272   0.725642   1.437173
# 96   3.396132   0.000000   4.973775   5.493259   1.298126   5.720153
# 97   5.860492   6.495527   5.149581   0.524228   4.663481   3.746872
# 98  19.324516  18.377250  10.459107  12.202528  12.552780  15.333102
# 99   7.614396   3.769543   3.676778   1.233718   5.042542   1.038476
#
#          6          7          8          9     ...       2690       2691  \
# 0    2.271520   5.429076   3.270809   3.656190  ...   1.647482   8.679513
# 1    7.570033   2.494695   3.598088   4.354450  ...   7.779929   2.699128
# 2    3.790801   3.300825   2.514376   2.215102  ...   3.520802   2.560227
# 3    0.438456   1.613441   0.362599   0.505446  ...   2.407752   0.086578
# 4    2.013236   4.733096   1.116497   1.174718  ...   1.364241   1.314842
# ..        ...        ...        ...        ...  ...        ...        ...
# 95   0.083664   2.052100   0.493781   0.282906  ...   6.314727  14.005163
# 96   0.673931   4.684951   3.218010   3.505624  ...   1.646173   2.222005
# 97   4.646953   0.188996   2.889318   3.326836  ...   4.054798   3.915228
# 98  19.943478  10.426634  17.628013  16.161064  ...  13.967982  15.474862
# 99   7.653571   5.130286  10.924089  12.405159  ...   4.830826   2.585062
#
#          2692       2693       2694       2695      2696       2697  \
# 0    7.284146   4.864713   4.286313   3.816320  4.898624   3.332100
# 1    4.500150   5.790674   1.771732   6.882947  4.988699   4.754615
# 2    0.655303   0.853697   0.145151   2.753036  0.677811   1.364425
# 3    1.068263   1.260528   0.606080   0.529119  0.465100   0.363603
# 4    1.665702   0.105266   2.161085   0.481156  1.927415   1.947346
# ..        ...        ...        ...        ...       ...        ...
# 95  10.943319   2.334262   4.411944   0.267027  5.826885   4.287649
# 96   3.159225   0.494732   1.406639   3.447656  0.058754   0.951591
# 97   1.635736   7.908170   4.722318   5.922861  3.447657   6.942625
# 98  11.183648  12.662843  11.758300  16.608793  8.828200  12.938282
# 99   5.265276   8.034254   3.613893  10.118942  3.957420   4.666321
#
#          2698       2699
# 0    4.018192   0.789190
# 1    2.547398   2.317015
# 2    0.332752   0.605965
# 3    0.470512   2.107961
# 4    0.603215   0.066929
# ..        ...        ...
# 95   4.174715   6.955507
# 96   1.581595   1.513537
# 97   4.830201   9.969791
# 98  10.745219  16.110011
# 99   3.728149   6.511287
#
# [100 rows x 2700 columns]

# %%
# save to csv
df_output.to_csv('GeneExpression_CRISPRa_perturb.csv')

# %% [markdown]
# # Run SERGIO with CRISPRi gene perturbations

# %%
sim = sergio(number_genes=100, number_bins = 9, number_sc = 300, noise_params = 1, decays=0.8, sampling_state=15, noise_type='dpd')
sim.build_graph(input_file_taregts ='steady-state_input_GRN_CRISPRai.txt', input_file_regs='steady-state_input_MRs_CRISPRi.txt', shared_coop_state=2)
sim.simulate()
expr = sim.getExpressions()
expr_clean_ss = np.concatenate(expr, axis = 1)
expr_clean_ss[1:5]
# Out:
# Start simulating new level
# There are 4 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 6 genes to simulate in this layer
# Done with current level
# Start simulating new level
# There are 90 genes to simulate in this layer
# Done with current level
# array([[10.78274018, 11.13218758,  5.06043398, ...,  2.36643327,
#          2.34448298,  2.8221197 ],
#        [ 6.00835688,  5.40109313,  3.05463151, ...,  0.81931436,
#          0.9967911 ,  2.78619637],
#        [ 6.50603545,  5.91269618,  3.90242039, ...,  0.71564068,
#          2.39213476,  1.54309601],
#        [ 2.15279361,  1.21912047,  2.42051223, ...,  0.68369825,
#          0.39858737,  2.08933086]])

# %%
expr_clean_ss 
df_output = pd.DataFrame(expr_clean_ss) 
df_output
# Out:
#          0          1          2          3          4         5         6     \
# 0   11.233255   9.772298   1.890599  11.182989   5.641545  3.077884  3.659470
# 1   10.782740  11.132188   5.060434  10.073664   2.370757  7.907955  2.732881
# 2    6.008357   5.401093   3.054632   2.512921   2.649927  3.735231  1.915484
# 3    6.506035   5.912696   3.902420   4.016664   2.785699  1.882797  1.411511
# 4    2.152794   1.219120   2.420512   5.487935   1.307277  4.628683  1.300990
# ..        ...        ...        ...        ...        ...       ...       ...
# 95   5.031996   5.703584   1.166218   3.277117   1.599402  0.842183  1.983411
# 96   4.728913   5.236330   1.549528   4.525837   3.466628  2.396713  3.306361
# 97   4.696677   5.492331   3.682270   5.891743   5.720661  5.036450  3.344571
# 98   9.746512   9.671936  14.739045   9.611418  12.998438  8.223306  7.437571
# 99   3.830853   3.948536   4.646442   4.712921   5.036875  4.185546  5.290310
#
#          7          8          9     ...      2690       2691       2692  \
# 0    5.555006   3.248342   6.216582  ...  3.970780   4.961139   1.236323
# 1    8.579135   2.838111   7.085616  ...  6.181729   4.413258   5.141877
# 2    3.501457   2.332326   1.947107  ...  1.027152   3.254472   2.946056
# 3    2.305684   2.226200   0.327215  ...  1.884069   0.273530   1.207183
# 4    3.711780   0.793018   3.787788  ...  3.510785   3.833648   1.507252
# ..        ...        ...        ...  ...       ...        ...        ...
# 95   0.072767   0.688547   1.711650  ...  1.766835   4.286285   1.515065
# 96   2.688660   3.466416   6.232346  ...  4.506086   4.179247   3.278353
# 97   4.469965   7.920156   7.869200  ...  4.440391   7.172792   6.232515
# 98  13.966746  14.983459  10.557949  ...  9.723624  12.692146  14.095643
# 99   4.479622   3.709419   4.719609  ...  9.069693   3.957023   1.015115
#
#         2693      2694      2695       2696      2697      2698      2699
# 0   0.154534  0.435478  1.634793   2.223439  1.157436  1.664555  1.988931
# 1   1.862084  2.439687  4.674641   2.684302  2.366433  2.344483  2.822120
# 2   0.880512  0.350398  2.807198   2.328763  0.819314  0.996791  2.786196
# 3   0.536839  0.458812  0.459290   2.038693  0.715641  2.392135  1.543096
# 4   0.988108  0.534437  0.621528   3.257090  0.683698  0.398587  2.089331
# ..       ...       ...       ...        ...       ...       ...       ...
# 95  7.431514  6.289063  4.911095   1.127049  8.875100  4.180903  2.716091
# 96  2.727062  0.255039  2.737508   4.523634  0.571754  2.455515  0.802091
# 97  4.409138  2.085968  3.280450   8.597780  3.241009  5.097239  6.043348
# 98  5.269393  6.087988  2.925358  12.832271  4.850549  8.106546  7.179789
# 99  3.204820  2.220408  4.920843   5.228516  1.776107  6.900375  7.986284
#
# [100 rows x 2700 columns]

# %%
# save to csv
df_output.to_csv('GeneExpression_CRISPRi_perturb.csv')
